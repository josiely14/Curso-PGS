# %% [markdown]
# <a href="https://colab.research.google.com/github/josiely14/Curso-PGS/blob/main/Exercic%C3%ADo%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Faça um algorítimo para ler dois números e imprimir a soma dos números lidos.

# %%
num1 = float(input("informe o 1 número "));
num2 = float(input("informe o 2 número"));
soma = num1 + num2

print (f"O resultado é {soma}");
# Out:
# informe o 1 número 3
# informe o 2 número 4
# O resultado é 7.0

# %% [markdown]
# Faça um algorítimo para ler três números e imprimir a soma média e produto dos números lidos

# %%
num1 = float(input("informe o 1 número"));
num2 = float(input("informe o 2 número "));
num3 = float(input("informe o 3 número "));
média = num1 + num2 + num3;

print (f"O resultado é {média/3}");
# Out:
# informe o 1 número4
# informe o 2 número 4
# informe o 3 número 5
# O resultado é 4.333333333333333

# %% [markdown]
# 3. Faça um algorítimo para ler dois números e imprimir o maior, o menor ou então dizer se são iguais.

# %%
num1 = float(input("informe o 1 número"));
num2 = float(input("informe o 2 número"));

if num1 > num2:
  print(f"O {num1} é maior");
elif num1 <num2:
   print(f"o {num1} é menor");
else:
   print(f"O resultado é igual");
# Out:
# informe o 1 número6
# informe o 2 número7
# o 6.0 é menor

# %% [markdown]
# 4. Faça um algorítimo para ler um número inteiro e dizer se o número lido é par ou impar.

# %%
if num1 % 2 == 0:
   print(f"O {num1} é par");
else:
   print(f"O {num1} é ipar");
# Out:
# O 6.0 é par

# %% [markdown]
# 5. Faça um algorítimo para ler dois números A e B e dizer se A é divisível por B.
#
# Algorítimo
# 1. Leia o primeiro número e salve em uma variável num1
# 2. Leia o segundo número e salve em uma variável num2
# 3. Verifique se num1 é divisível pelo num2:
# - se o resto for maior que zero mostre que é divisível
# - senão mostre que não é divisel

# %%
num1 = int(input("Digite o primeiro número:"))
num2 = int(input("Digite o segundo número"))
print(f"{num1}")
if num1 % num2  != 0:
   print(f"não")
print(f" é divisível por {num2}")
# Out:
# Digite o primeiro número:6
# Digite o segundo número2
# 6
#  é divisível por 2

# %% [markdown]
# 6.Faça um algoritmo para ler dois números e imprimi-los em ordem crescente.
#
# Algorítimo
# 1. Leia o primeiro número e salve na variável num1
# 2. Leia o segundo número e salve na variável num2
# 3.
# 4. Mostrar o menor número
# 5. Mostrar o maior em seguida

# %%
num1 = float(input("Digite o primeiro número"))
